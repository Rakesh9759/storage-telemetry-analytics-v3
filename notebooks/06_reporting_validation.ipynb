# %%
from pathlib import Path

md_path = Path("../assets/sample_reports/storage_telemetry_summary.md")
html_path = Path("../assets/sample_reports/storage_telemetry_summary.html")

print(md_path.exists(), html_path.exists())

print(md_path.read_text())
# Out:
# True True
# # Storage Telemetry Investigation Summary
#
# Generated at: 2026-04-07T22:14:29.143089 UTC
#
# ## 1. Run Overview
#
# - Total devices analyzed: **5**
# - Total anomalies detected: **8423**
# - Critical anomalies: **726**
# - High severity anomalies: **324**
# - Average device latency: **86.08 ms**
# - Average device utilization: **36.36%**
#
# ## 2. Executive Summary
#
# This report summarizes storage telemetry behavior across analyzed devices, with emphasis on anomaly frequency, severity distribution, workload patterns, and likely root-cause signals.
#
# ## 3. Dominant Workload Patterns
#
# - **balanced**: 4 device(s)
# - **latency_sensitive**: 1 device(s)
#
# ## 4. Most Affected Devices
#
# - **sda** â€” anomalies: 1604, critical: 198, dominant workload: balanced, avg latency: 1.63 ms
# - **sdb** â€” anomalies: 2526, critical: 171, dominant workload: latency_sensitive, avg latency: 426.54 ms
# - **nvme0n1** â€” anomalies: 1391, critical: 146, dominant workload: balanced, avg latency: 0.38 ms
# - **nvme1n1** â€” anomalies: 1520, critical: 114, dominant workload: balanced, avg latency: 0.79 ms
# - **dm-0** â€” anomalies: 1382, critical: 97, dominant workload: balanced, avg latency: 1.05 ms
#
# ## 5. Top Root-Cause Signals
#
# - **Anomalous behavior detected** (workload: latency_sensitive, anomalies: 941, critical: 172)
# - **Latency anomaly detected without clear saturation signal** (workload: latency_sensitive, anomalies: 747, critical: 71)
# - **Composite saturation signal indicates elevated device stress** (workload: latency_sensitive, anomalies: 491, critical: 65)
# - **Composite saturation signal indicates elevated device stress** (workload: saturated, anomalies: 276, critical: 64)
# - **Anomalous behavior detected** (workload: balanced, anomalies: 2148, critical: 63)
#
# ## 6. Recommended Next Checks
#
# - Review critical anomaly windows first, prioritizing devices with repeated latency and saturation signals.
# - Correlate high-utilization and queue-depth periods with latency spikes to validate saturation-driven degradation.
